# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
datapath = "D:\\Dati_DSO\\FCC\\"

# %% [raw]
# ls $datapath

# %%
df = pd.read_csv(datapath+'202312061650_LED_SERAMP.txt', sep=" ", header=None, names=["frame", "x1", "y1", "x2", "y2", "x3", "y3", "x4", "y4"])

df
# Out:
#           frame            x1      y1            x2      y2            x3  \
# 0           1.0 -3.500000e-07  0.0005 -3.500000e-07  0.0012 -3.500000e-07
# 1           1.0 -3.490000e-07 -0.0001 -3.490000e-07  0.0016 -3.490000e-07
# 2           1.0 -3.480000e-07  0.0001 -3.480000e-07  0.0014 -3.480000e-07
# 3           1.0 -3.470000e-07  0.0001 -3.470000e-07  0.0012 -3.470000e-07
# 4           1.0 -3.460000e-07  0.0009 -3.460000e-07  0.0006 -3.460000e-07
# ...         ...           ...     ...           ...     ...           ...
# 4219595  6028.0  3.450000e-07  0.0005  3.450000e-07  0.0004  3.450000e-07
# 4219596  6028.0  3.460000e-07  0.0003  3.460000e-07  0.0004  3.460000e-07
# 4219597  6028.0  3.470000e-07  0.0007  3.470000e-07 -0.0004  3.470000e-07
# 4219598  6028.0  3.480000e-07  0.0003  3.480000e-07 -0.0008  3.480000e-07
# 4219599  6028.0  3.490000e-07  0.0007  3.490000e-07 -0.0012  3.490000e-07
#
#             y3            x4     y4
# 0        0.002 -3.500000e-07 -0.002
# ...

# %%
#dd = df.query('frame==100')
plt.plot(df.x1, df.y1, lw=0.004)

# %%
#dd = df.query('frame==100')
import matplotlib as mlp
plt.hist2d(df.x1, df.y1,  bins=200, norm=mlp.colors.LogNorm())
plt.show()

# %%
CH1 = []
for frame in df.frame.unique():
    d = df.query(f'frame=={frame}')
    CH1+=[np.max(np.abs(d.y1))]
CH1 = np.array(CH1)

# %%
plt.hist(CH1, bins=50, density=True, histtype='step')

plt.legend()
#plt.yscale('log')
plt.xlabel('C1 amplitudes')
plt.title('no filter side')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.hist(CH1, bins=50, density=True, histtype='step')

plt.legend()
plt.yscale('log')
plt.xlabel('C1 amplitudes')
plt.title('no filter side')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
