# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
datapath = "D:\\Dati_DSO\\FCC\\"

# %% [raw]
# ls $datapath

# %%
df_UG1v = pd.read_csv(datapath+'202401051645_BGO_verticale_filtroshortUG1sotto_gain28.txt', sep=" ", skiprows=22)

df_UG1v
# Out:
#           frame    Time_Stamp          Time     C1    C2            C3  \
# 0        1845.0  1.704470e+09 -7.000000e-07  0.002  0.00 -4.000000e-03
# 1        1845.0  1.704470e+09 -6.990000e-07 -0.006  0.00  5.551115e-17
# 2        1845.0  1.704470e+09 -6.980000e-07  0.008  0.00 -4.000000e-03
# 3        1845.0  1.704470e+09 -6.970000e-07  0.006  0.00  5.551115e-17
# 4        1845.0  1.704470e+09 -6.960000e-07  0.004  0.00  5.551115e-17
# ...         ...           ...           ...    ...   ...           ...
# 8962056  6400.0  1.704678e+09 -4.400000e-08  0.002  0.00 -1.200000e-02
# 8962057  6400.0  1.704678e+09 -4.300000e-08 -0.008  0.00 -8.000000e-03
# 8962058  6400.0  1.704678e+09 -4.200000e-08  0.002  0.02 -8.000000e-03
# 8962059  6400.0  1.704678e+09 -4.100000e-08 -0.002  0.00 -8.000000e-03
# 8962060  6400.0  1.704678e+09 -4.000000e-08  0.010  0.02           NaN
#
#                    C4
# 0        5.551115e-17
# 1        5.551115e-17
# 2        5.551115e-17
# ...

# %%
df_UG1 = pd.read_csv(datapath+'202401041420_BGO_orizzontale_filtroshortUG1_gain28.txt', sep=" ", skiprows=22)

df_UG1
# Out:
#           frame    Time_Stamp          Time     C1    C2            C3  \
# 0           1.0  1.704375e+09 -7.000000e-07  0.004  0.00 -4.000000e-03
# 1           1.0  1.704375e+09 -6.990000e-07  0.004  0.00  5.551115e-17
# 2           1.0  1.704375e+09 -6.980000e-07  0.000  0.02 -4.000000e-03
# 3           1.0  1.704375e+09 -6.970000e-07 -0.006  0.00  5.551115e-17
# 4           1.0  1.704375e+09 -6.960000e-07 -0.002  0.02  5.551115e-17
# ...         ...           ...           ...    ...   ...           ...
# 2581595  1844.0  1.704445e+09  6.950000e-07  0.000  0.00  8.000000e-03
# 2581596  1844.0  1.704445e+09  6.960000e-07  0.004  0.02  8.000000e-03
# 2581597  1844.0  1.704445e+09  6.970000e-07  0.002  0.00  8.000000e-03
# 2581598  1844.0  1.704445e+09  6.980000e-07 -0.004  0.00  4.000000e-03
# 2581599  1844.0  1.704445e+09  6.990000e-07 -0.006  0.00  4.000000e-03
#
#                    C4
# 0       -4.000000e-03
# 1        5.551115e-17
# 2       -4.000000e-03
# ...

# %%
df_nofilters = pd.read_csv(datapath+' 202321121312_BGOorizzontalesenzafiltrogain28.txt', sep=" ", header=None, names=["frame", "Time", "C1", "x2", "C2", "x3", "C3", "x4", "C4"]) #, skiprows=22)

df_nofilters
# Out:
#           frame          Time    C1            x2    C2            x3  \
# 0           1.0 -7.000000e-07  0.02 -7.000000e-07  0.02 -7.000000e-07
# 1           1.0 -6.990000e-07  0.02 -6.990000e-07  0.00 -6.990000e-07
# 2           1.0 -6.980000e-07  0.04 -6.980000e-07  0.02 -6.980000e-07
# 3           1.0 -6.970000e-07  0.04 -6.970000e-07  0.00 -6.970000e-07
# 4           1.0 -6.960000e-07  0.02 -6.960000e-07  0.00 -6.960000e-07
# ...         ...           ...   ...           ...   ...           ...
# 4131395  2951.0  6.950000e-07  0.00  6.950000e-07  0.00  6.950000e-07
# 4131396  2951.0  6.960000e-07  0.02  6.960000e-07  0.00  6.960000e-07
# 4131397  2951.0  6.970000e-07  0.02  6.970000e-07  0.02  6.970000e-07
# 4131398  2951.0  6.980000e-07  0.02  6.980000e-07  0.00  6.980000e-07
# 4131399  2951.0  6.990000e-07  0.02  6.990000e-07  0.02  6.990000e-07
#
#                    C3            x4            C4
# 0        5.551115e-17 -7.000000e-07 -8.000000e-03
# ...

# %%
df_shortpass = pd.read_csv(datapath+' 202312151837_BGO_orizzontale_filtroshort400_gain28.txt', sep=" ", header=None, names=["frame", "Time", "C1", "x2", "C2", "x3", "C3", "x4", "C4"]) #, skiprows=22

df_shortpass
# Out:
#           frame          Time     C1            x2    C2            x3     C3  \
# 0           1.0 -7.000000e-07  0.006 -7.000000e-07  0.01 -7.000000e-07  0.002
# 1           1.0 -6.990000e-07 -0.002 -6.990000e-07  0.01 -6.990000e-07  0.002
# 2           1.0 -6.980000e-07 -0.002 -6.980000e-07  0.03 -6.980000e-07 -0.002
# 3           1.0 -6.970000e-07 -0.002 -6.970000e-07  0.01 -6.970000e-07 -0.002
# 4           1.0 -6.960000e-07 -0.006 -6.960000e-07  0.01 -6.960000e-07  0.002
# ...         ...           ...    ...           ...   ...           ...    ...
# 9388395  6706.0  6.950000e-07 -0.002  6.950000e-07  0.03  6.950000e-07  0.006
# 9388396  6706.0  6.960000e-07 -0.006  6.960000e-07 -0.01  6.960000e-07  0.002
# 9388397  6706.0  6.970000e-07 -0.006  6.970000e-07  0.01  6.970000e-07  0.002
# 9388398  6706.0  6.980000e-07 -0.002  6.980000e-07 -0.01  6.980000e-07  0.002
# 9388399  6706.0  6.990000e-07  0.006  6.990000e-07  0.01  6.990000e-07  0.006
#
# ...

# %%
dd = df_UG1.query('2<frame')
frame = dd.frame.min()
cv = dd.query(f'frame=={frame}').Time.values
binwidth = abs(cv[1]-cv[0])/2
xbins = cv - binwidth
fxbins = np.append(xbins, [xbins[-1]+binwidth])

hy, hx = np.histogram(dd.Time , weights=dd.C1/len(dd.frame.unique()), bins=fxbins)
hx = (hx[1:]+hx[:-1])/2
plt.plot(hx, hy, label = 'C1 w filter')
plt.title('BGO horizzontal, w UG1 filter')
plt.xlabel('Time [ns]')
plt.ylabel('Amplitude [V]')
plt.legend()
plt.grid()
plt.show()

# %%
dd = df_UG1.query('2<frame')
frame = dd.frame.min()
cv = dd.query(f'frame=={frame}').Time.values
binwidth = abs(cv[1]-cv[0])/2
xbins = cv - binwidth
fxbins = np.append(xbins, [xbins[-1]+binwidth])

hy, hx = np.histogram(dd.Time , weights=-dd.C2/len(dd.frame.unique()), bins=fxbins)
hx = (hx[1:]+hx[:-1])/2
plt.plot(hx, hy, label = 'C2 no filter', color='C1')
plt.title('BGO horizzontal, w UG1 filter')
plt.xlabel('Time [ns]')
plt.ylabel('Amplitude [V]')
plt.legend()
plt.grid()
plt.show()

# %%
dd = df_UG1v.query('2<frame')
frame = dd.frame.min()
cv = dd.query(f'frame=={frame}').Time.values
binwidth = abs(cv[1]-cv[0])/2
xbins = cv - binwidth
fxbins = np.append(xbins, [xbins[-1]+binwidth])

hy, hx = np.histogram(dd.Time , weights=dd.C1/len(dd.frame.unique()), bins=fxbins)
hx = (hx[1:]+hx[:-1])/2
plt.plot(hx, hy, label = 'C1 w filter')
plt.title('BGO vertical, w UG1 filter')
plt.xlabel('Time [ns]')
plt.ylabel('Amplitude [V]')
plt.legend()
plt.grid()
plt.show()

# %%
dd = df_UG1v.query('2<frame')
frame = dd.frame.min()
cv = dd.query(f'frame=={frame}').Time.values
binwidth = abs(cv[1]-cv[0])/2
xbins = cv - binwidth
fxbins = np.append(xbins, [xbins[-1]+binwidth])

hy, hx = np.histogram(dd.Time , weights=-dd.C2/len(dd.frame.unique()), bins=fxbins)
hx = (hx[1:]+hx[:-1])/2
plt.plot(hx, hy, label = 'C2 no filter', color='C1')
plt.title('BGO vertical, w UG1 filter')
plt.xlabel('Time [ns]')
plt.ylabel('Amplitude [V]')
plt.legend()
plt.grid()
plt.show()

# %%
dd = df_nofilters.query('2<frame')
frame = dd.frame.min()
cv = dd.query(f'frame=={frame}').Time.values
binwidth = abs(cv[1]-cv[0])/2
xbins = cv - binwidth
fxbins = np.append(xbins, [xbins[-1]+binwidth])

hy, hx = np.histogram(dd.Time , weights=dd.C1/len(dd.frame.unique()), bins=fxbins)
hx = (hx[1:]+hx[:-1])/2
plt.plot(hx, hy, label = 'C1 no filter')
plt.title('BGO horizzontal, no filter')
plt.xlabel('Time [ns]')
plt.ylabel('Amplitude [V]')
plt.legend()
plt.grid()
plt.show()

# %%
dd = df_nofilters.query('2<frame')
frame = dd.frame.min()
cv = dd.query(f'frame=={frame}').Time.values
binwidth = abs(cv[1]-cv[0])/2
xbins = cv - binwidth
fxbins = np.append(xbins, [xbins[-1]+binwidth])

hy, hx = np.histogram(dd.Time , weights=-dd.C2/len(dd.frame.unique()), bins=fxbins)
hx = (hx[1:]+hx[:-1])/2
plt.plot(hx, hy, label = 'C2 no filter', color='C1')
plt.title('BGO horizzontal, no filter')
plt.xlabel('Time [ns]')
plt.ylabel('Amplitude [V]')
plt.legend()
plt.grid()
plt.show()

# %%
dd = df_shortpass.query('2<frame')
frame = dd.frame.min()
cv = dd.query(f'frame=={frame}').Time.values
binwidth = abs(cv[1]-cv[0])/2
xbins = cv - binwidth
fxbins = np.append(xbins, [xbins[-1]+binwidth])

hy, hx = np.histogram(dd.Time , weights=dd.C1/len(dd.frame.unique()), bins=fxbins)
hx = (hx[1:]+hx[:-1])/2
plt.plot(hx, hy, label = 'C1 filter')
plt.title('BGO horizzontal, shortpass filter')
plt.xlabel('Time [ns]')
plt.ylabel('Amplitude [V]')
plt.legend()
plt.grid()
plt.show()

# %%
dd = df_shortpass.query('2<frame')
frame = dd.frame.min()
cv = dd.query(f'frame=={frame}').Time.values
binwidth = abs(cv[1]-cv[0])/2
xbins = cv - binwidth
fxbins = np.append(xbins, [xbins[-1]+binwidth])

hy, hx = np.histogram(dd.Time , weights=-dd.C2/len(dd.frame.unique()), bins=fxbins)
hx = (hx[1:]+hx[:-1])/2
plt.plot(hx, hy, label = 'C2 no filter', color='C1')
plt.title('BGO horizzontal, shortpass filter')
plt.xlabel('Time [ns]')
plt.ylabel('Amplitude [V]')
plt.legend()
plt.grid()
plt.show()

# %%
dframes = {'nof_h': df_nofilters,
           'ug1_v': df_UG1v,
           'ug1_h': df_UG1,
           'sp_h': df_shortpass}

amplitudes = {}

# %% [raw]
# df = df_UG1v
# CH2 = []
# CH1 = []
# for frame in df.frame.unique():
#     d = df.query(f'frame=={frame}')
#     CH2+=[np.max(np.abs(d.C2))]
#     CH1+=[np.max(np.abs(d.C1))]
# CH1 = np.array(CH1)
# CH2 = np.array(CH2)

# %%
for k in dframes.keys():
    df = dframes[k]
    CH2 = []
    CH1 = []
    for frame in df.frame.unique():
        d = df.query(f'frame=={frame}')
        CH2+=[np.max(np.abs(d.C2))]
        CH1+=[np.max(np.abs(d.C1))]
    CH1 = np.array(CH1)
    CH2 = np.array(CH2)
    amplitudes[k] = {'ch1': CH1, 'ch2': CH2 }
    print('done')
# Out:
# done
# done
# done
# done

# %%
for k in amplitudes.keys():
    
    plt.hist(amplitudes[k]['ch2'], bins=50, range=[0.05, 3], density=True, histtype='step', label=k)


plt.legend()
#plt.yscale('log')
plt.xlabel('C2 amplitudes')
plt.title('no filter side')
plt.show()

# %%
for k in amplitudes.keys():
    
    plt.hist(amplitudes[k]['ch1'], bins=50, density=True, histtype='step', label=k)


plt.legend()
plt.yscale('log')
plt.xlabel('C1 amplitudes')
plt.title('filter side')
plt.show()

# %%
for k in ['ug1v', 'ug1h']:
    
    plt.hist(amplitudes[k]['ch1'], bins=10, density=True, histtype='step', label=k)

plt.legend()
plt.yscale('log')
plt.xlabel('C1 amplitudes')
plt.title('filter side')
plt.show()

# %%
df = df_UG1v
#%matplotlib widget
i=0
j=0
plots_per_row=3
FRAMES=df.frame.unique()[amplitudes['ug1v']['ch2']>0.5][:33]
fig, axs = plt.subplots(math.ceil(len(FRAMES)/plots_per_row), plots_per_row, figsize=(10, 24))
fig.tight_layout(pad=2.5)
for frame in FRAMES:
    d = df.query(f'frame=={frame}')
    axs[i][j].plot(d.Time*1E6, d.C1, lw=1, label='BGO+UG1')
    axs[i][j].plot(d.Time*1E6, abs(d.C2/20), lw=1, label='BGO/10')
    axs[i][j].set_xlabel(r'Time [$\mu$s]')#, size=14)
    axs[i][j].set_ylabel('Amplitude [V]')#, size=14)
    axs[i][j].grid()
    axs[i][j].legend()
    j+=1
    if j%plots_per_row==0:
        i+=1
        j=0
plt.show()

# %%
dd = df_UG1v
dd = dd[dd['frame'].isin(dd.frame.unique()[amplitudes['ug1v']['ch2']>0.5])]

frame = dd.frame.min()
cv = dd.query(f'frame=={frame}').Time.values
binwidth = abs(cv[1]-cv[0])/2
xbins = cv - binwidth
fxbins = np.append(xbins, [xbins[-1]+binwidth])

plt.hist(dd.Time , weights=(dd.C1-0.0016)/len(dd.frame.unique())/0.0125, bins=fxbins, histtype='step')
plt.hist(dd.Time , weights=abs(dd.C2)/len(dd.frame.unique()), bins=fxbins, histtype='step')
#plt.plot(dd.Time, dd.C1, color='C1')
plt.show()

# %%
dd = df_UG1v
dd = dd[dd['frame'].isin(dd.frame.unique()[amplitudes['ug1v']['ch2']>0.5])]

frame = dd.frame.min()
cv = dd.query(f'frame=={frame}').Time.values
binwidth = abs(cv[1]-cv[0])/2
xbins = cv - binwidth
fxbins = np.append(xbins, [xbins[-1]+binwidth])

plt.hist(dd.Time , weights=(dd.C1-0.0016)/len(dd.frame.unique())/0.0125, bins=fxbins, histtype='step')
plt.hist(dd.Time , weights=abs(dd.C2)/len(dd.frame.unique()), bins=fxbins, histtype='step')
plt.xlim(-6E-7, -2E-7)
#plt.plot(dd.Time, dd.C1, color='C1')
plt.show()

# %%
dd = df_UG1v
dd = dd[dd['frame'].isin(dd.frame.unique()[amplitudes['ug1v']['ch2']>0.5])]

frame = dd.frame.min()
cv = dd.query(f'frame=={frame}').Time.values
binwidth = abs(cv[1]-cv[0])/2
xbins = cv - binwidth
fxbins = np.append(xbins, [xbins[-1]+binwidth])

plt.hist(dd.Time , weights=(dd.C1-0.0016)/len(dd.frame.unique())/0.0125, bins=fxbins, histtype='step', label='UG1 filter')

dd = df_nofilters
dd = dd[dd['frame'].isin(dd.frame.unique()[amplitudes['nofh']['ch2']>0.5])]

frame = dd.frame.min()
cv = dd.query(f'frame=={frame}').Time.values
binwidth = abs(cv[1]-cv[0])/2
xbins = cv - binwidth
fxbins = np.append(xbins, [xbins[-1]+binwidth])

plt.hist(dd.Time , weights=abs(dd.C1-0.0016)/len(dd.frame.unique())/1, bins=fxbins, histtype='step', label='no filter')
#plt.hist(dd.Time , weights=abs(dd.C2-0.0016)/len(dd.frame.unique())/1, bins=fxbins, histtype='step')
plt.xlim(-6E-7, -2E-7)
plt.legend(loc=2)
plt.xlabel('Time [s]')
#plt.plot(dd.Time, dd.C1, color='C1')
plt.show()

# %%
dd = df_nofilters
dd = dd[dd['frame'].isin(dd.frame.unique()[amplitudes['nofh']['ch2']>0.5])]

frame = dd.frame.min()
cv = dd.query(f'frame=={frame}').Time.values
binwidth = abs(cv[1]-cv[0])/2
xbins = cv - binwidth
fxbins = np.append(xbins, [xbins[-1]+binwidth])

plt.hist(dd.Time, weights=(dd.C1)/len(dd.frame.unique())/0.35, bins=fxbins, histtype='step', label='C1')
hy, hx = np.histogram(dd.Time , weights=(dd.C1)/len(dd.frame.unique())/0.35, bins=fxbins)
#plt.plot(dd.Time, dd.C1, color='C1')
plt.grid()

plt.legend()
plt.show()

# %%
def func(x, a, tr, tf, t0, c):
    d=0
    y = c + (a*(1-np.exp(-(x-t0)/tr))*(np.exp(-(x-t0)/tf))+d)*(x>t0) + 0*(x<=t0)
    return y

from iminuit import Minuit
from iminuit.cost import LeastSquares

wf = pd.DataFrame({'x':(hx[:-1]+hx[1:])/2, 'y':hy})

wf_cutted = wf.query('x<200E-9')
xdata = wf_cutted.x.values
ydata = wf_cutted.y.values
sigmas=1

least_squares = LeastSquares(xdata*1E9, ydata, sigmas, func)
m = Minuit(least_squares, a=1, tr=25, tf=300, t0=-400, c=0.05)#, d=-0.4)

m.params

m.migrad();

plt.scatter(xdata*1E9, ydata, s=5, color='black', label="data")
plt.plot(xdata*1E9, func(xdata*1E9, *m.values), label="fit", color='red')
fit_info = [] #[ f"$\\chi^2$ / $n_\\mathrm{{dof}}$ = {m.fval:.1f} / {len(xdata) - m.nfit}" ]
for p, v, e in zip(m.parameters, m.values, m.errors):
    fit_info.append(f"{p} = ${v:.3f} \\pm {e:.3f}$")
plt.legend(title="\n".join(fit_info))
plt.xlabel('Time [ns]')
plt.ylabel('y [V]')
plt.grid()
plt.show()
