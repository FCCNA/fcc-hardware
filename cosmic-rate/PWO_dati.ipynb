# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import random
import mpl_toolkits.mplot3d as a3
import pandas as pd

# %%
datapath = "~/Desktop/Tesi/"
df = pd.read_csv(datapath+'20230830-1130_pwo.txt', sep = " ", header = None, names = ["frame", "x1", "y1", "x2", "y2", "x3", "y3", "x4", "y4"])

# %%
df
# Out:
#           frame            x1      y1            x2      y2            x3  \
# 0           1.0 -7.000000e-07 -0.0008 -7.000000e-07  0.0008 -7.000000e-07
# 1           1.0 -6.990000e-07 -0.0008 -6.990000e-07  0.0008 -6.990000e-07
# 2           1.0 -6.980000e-07 -0.0008 -6.980000e-07  0.0000 -6.980000e-07
# 3           1.0 -6.970000e-07 -0.0008 -6.970000e-07  0.0008 -6.970000e-07
# 4           1.0 -6.960000e-07 -0.0008 -6.960000e-07  0.0000 -6.960000e-07
# ...         ...           ...     ...           ...     ...           ...
# 9084595  6489.0  6.950000e-07 -0.0008  6.950000e-07  0.0008  6.950000e-07
# 9084596  6489.0  6.960000e-07 -0.0008  6.960000e-07  0.0008  6.960000e-07
# 9084597  6489.0  6.970000e-07 -0.0008  6.970000e-07  0.0008  6.970000e-07
# 9084598  6489.0  6.980000e-07 -0.0008  6.980000e-07  0.0008  6.980000e-07
# 9084599  6489.0  6.990000e-07 -0.0008  6.990000e-07  0.0008  6.990000e-07
#
#             y3            x4     y4
# 0       -0.004 -7.000000e-07  0.001
# 1       -0.004 -6.990000e-07 -0.003
# 2       -0.004 -6.980000e-07 -0.001
# 3       -0.004 -6.970000e-07 -0.003
# 4       -0.004 -6.960000e-07 -0.001
# ...        ...           ...    ...
# 9084595 -0.002  6.950000e-07  0.005
# 9084596 -0.002  6.960000e-07  0.005
# 9084597 -0.002  6.970000e-07  0.005
# 9084598 -0.002  6.980000e-07  0.003
# 9084599 -0.002  6.990000e-07  0.005
#
# [9084600 rows x 9 columns]

# %%
frame_to_plot = 90
selected_frame = df[df['frame'] == frame_to_plot]


plt.figure(figsize=(10, 6))
plt.plot(selected_frame['x1'], selected_frame['y1'])
plt.title(f'Plot x1 vs y1 per il frame {frame_to_plot}')
plt.xlabel('x1 (a.u.)')
plt.ylabel('y1 (a.u.)')
plt.show()


plt.figure(figsize=(10, 6))
plt.plot(selected_frame['x2'], selected_frame['y2'])
plt.title(f'Plot x2 vs y2 per il frame {frame_to_plot}')
plt.xlabel('x2')
plt.ylabel('y2')
plt.show()

plt.figure(figsize=(10, 6))
plt.plot(selected_frame['x3'], selected_frame['y3'])
plt.title(f'Plot x3 vs y3 per il frame {frame_to_plot}')
plt.xlabel('x3')
plt.ylabel('y3')
plt.show()

plt.figure(figsize=(10, 6))
plt.plot(selected_frame['x4'], selected_frame['y4'])
plt.title(f'Plot x4 vs y4 per il frame {frame_to_plot}')
plt.xlabel('x4')
plt.ylabel('y4')
plt.show()

# %% [markdown]
# ## Ampiezze

# %%
unique_frames = df['frame'].unique()

max_values_dict = {'frame': [], 'max_y1': [], 'max_y2': [], 'max_y3' : [], 'max_y4': []}

for frame in unique_frames:
    frame_data = df[df['frame'] == frame]
    max_y1 = frame_data['y1'].min()
    max_y2 = frame_data['y2'].min()
    max_y3 = frame_data['y3'].min()
    max_y4 = frame_data['y4'].min()
    
    
    max_values_dict['frame'].append(frame)
    max_values_dict['max_y1'].append(max_y1)
    max_values_dict['max_y2'].append(max_y2)
    max_values_dict['max_y3'].append(max_y3)
    max_values_dict['max_y4'].append(max_y4)

max_values_df = pd.DataFrame(max_values_dict)

plt.figure(figsize=(10, 6))
plt.hist(max_values_df['max_y1'], bins=20, color='blue', alpha=0.7, label='max_y1')
plt.hist(max_values_df['max_y2'], bins=20, color='orange', alpha=0.7, label='max_y2')
plt.hist(max_values_df['max_y3'], bins=20, color='green', alpha=0.7, label='max_y3')
plt.hist(max_values_df['max_y4'], bins=20, color='red', alpha=0.7, label='max_y4')
plt.title('Ampiezze')
plt.xlabel('max y1,y2,y3,y4')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %% [markdown]
# ## Integrale

# %%
int_dict = {'frame': [], 'sum_y1': [], 'sum_y2': [], 'sum_y3':[], 'sum_y4':[]}

for frame in unique_frames:
    frame_data = df[df['frame'] == frame]
    sum_y1 = frame_data['y1'].sum()
    sum_y2 = frame_data['y2'].sum()
    sum_y3 = frame_data['y3'].sum()
    sum_y4 = frame_data['y4'].sum()
    
    int_dict['frame'].append(frame)
    int_dict['sum_y1'].append(sum_y1)
    int_dict['sum_y2'].append(sum_y2)
    int_dict['sum_y3'].append(sum_y3)
    int_dict['sum_y4'].append(sum_y4)
    

int_df = pd.DataFrame(int_dict)


plt.figure(figsize=(10, 6))
plt.hist(int_df['sum_y1'], bins=20, color='blue', alpha=0.7, label='Lettura 1')
plt.hist(int_df['sum_y2'], bins=20, color='orange', alpha=0.7, label='Lettura 2')
#plt.hist(int_df['sum_y3'], bins=20, color='green', alpha=0.7, label='Scintillatore 1')
#plt.hist(int_df['sum_y4'], bins=20, color='red', alpha=0.7, label='Scintillatore 2')
plt.title('Integrale')
plt.xlabel('Carica raccolta (a.u.)')
plt.ylabel('Frequency')
plt.legend()
plt.xlim(- 20, 0)
plt.show()

events_tot = len(int_df)
print("Numero di eventi totali:", events_tot )
# Out:
# Numero di eventi totali: 6489

# %%
int_dict1 = {'frame': [], 'sum_y1': [], 'sum_y2': [], 'sum_y3':[], 'sum_y4':[]}

for frame in unique_frames:
    frame_data = df[df['frame'] == frame]
    sum_y1 = frame_data['y1'].sum()
    sum_y2 = frame_data['y2'].sum()
    sum_y3 = frame_data['y3'].sum()
    sum_y4 = frame_data['y4'].sum()
    
    if  sum_y1 <= -0.5 and sum_y2 <= -0.5 and sum_y3 <= 0 and sum_y4 <= 0:
        int_dict1['frame'].append(frame)
        int_dict1['sum_y1'].append(sum_y1)
        int_dict1['sum_y2'].append(sum_y2)
        int_dict1['sum_y3'].append(sum_y3)
        int_dict1['sum_y4'].append(sum_y4)

int_df1 = pd.DataFrame(int_dict1)

plt.figure(figsize=(10, 6))
plt.hist(int_df1['sum_y1'], bins=20, color='blue', alpha=0.7, label='sum_y1')
plt.hist(int_df1['sum_y2'], bins=20, color='orange', alpha=0.7, label='sum_y2')
#plt.hist(int_df1['sum_y3'], bins=20, color='green', alpha=0.7, label='sum_y3')
#plt.hist(int_df1['sum_y4'], bins=20, color='red', alpha=0.7, label='sum_y4')
plt.title('Integrale Cut Off')
plt.xlabel('sum y1 y2 y3 y4')
plt.ylabel('Frequency')
plt.legend()
plt.xlim(-20, 0)
plt.show()

events = len(int_df1)
print("Numero di eventi:", events )
print("Percentuale: ", events/events_tot * 100, "%")
# Out:
# Numero di eventi: 2234
# Percentuale:  34.427492679919865 %

# %%
x = max_values_df['max_y1'] #ampiezza
y = int_df['sum_y1'] #carica

plt.figure(figsize=(8, 6)) 
plt.scatter(x, y, marker='o', linestyle='-', color='b', label='Dati')

plt.title('Carica vs Ampiezza (ch1 PWO)')
plt.xlabel('Ampiezze')
plt.ylabel('Carica')
plt.legend()


plt.show()

# %%
correlation_matrix = np.corrcoef(x, y)
correlation_coefficient = correlation_matrix[0, 1]

print(f"Indice di correlazione: {correlation_coefficient}")
# Out:
# Indice di correlazione: 0.9784259894194457

# %% [markdown]
# Integriamo solo l' intervallo dove c'è il picco:

# %%
int_dict = {'frame': [], 'sum_y1': [], 'sum_y2': []}

for frame in unique_frames:
    frame_data = df[df['frame'] == frame]
    
    # Filtraggio dei dati per y1 e y2 compresi tra -5 e -2
    filtered_data = frame_data[(frame_data['x1'] >= -6) & (frame_data['x1'] <= -2)]
    
    sum_y1 = filtered_data['y1'].sum()
    
    filtered_data = frame_data[(frame_data['x2'] >= -6) & (frame_data['x2'] <= -2)]
    sum_y2 = filtered_data['y2'].sum()
    
    int_dict['frame'].append(frame)
    int_dict['sum_y1'].append(sum_y1)
    int_dict['sum_y2'].append(sum_y2)

int_df = pd.DataFrame(int_dict)

plt.figure(figsize=(10, 6))
plt.hist(int_df['sum_y1'], bins=20, color='blue', alpha=0.7, label='sum_y1')
plt.hist(int_df['sum_y2'], bins=20, color='orange', alpha=0.7, label='sum_y2')
plt.title('Integrale')
plt.xlabel('sum y1 y2')
plt.ylabel('Frequency')
plt.legend()
plt.show()

events_tot = len(int_df)
print("Numero di eventi totali:", events_tot)
# Out:
# Numero di eventi totali: 6489

# %% [markdown]
# ## Cumulativa

# %%
cumulative_sum = df['y1'].cumsum()

# Crea un grafico
plt.figure(figsize=(10, 6))
#plt.plot(df['y1'], label='y1')  # Plot di y1 su x
plt.plot( - cumulative_sum, label='Somma Cumulativa di y1')  # Plot della somma cumulativa su y

plt.xlabel('Indice')
plt.ylabel('Valore')
plt.legend()
plt.grid(True)
plt.title('Grafico di y1 e Somma Cumulativa di y1')
plt.show()

# %%
unique_frames = df['frame'].unique()
cumsum_dict = {'frame': [], 'cumsum_y1': [], 'cumsum_y2': []}

for frame in unique_frames:
    frame_data = df[df['frame'] == frame]
    cumsum_y1 = frame_data['y1'].cumsum()
    cumsum_y2 = frame_data['y2'].cumsum()
   
    
    cumsum_dict['frame'].append(frame)
    cumsum_dict['cumsum_y1'].append(cumsum_y1)
    cumsum_dict['cumsum_y2'].append(cumsum_y2)
    

cumsum_df = pd.DataFrame(cumsum_dict)

# %%
print(frame_data['y1'])
# Out:
# 9083200    0.0000
# 9083201    0.0000
# 9083202    0.0000
# 9083203    0.0000
# 9083204    0.0000
#             ...
# 9084595   -0.0008
# 9084596   -0.0008
# 9084597   -0.0008
# 9084598   -0.0008
# 9084599   -0.0008
# Name: y1, Length: 1400, dtype: float64

# %%
cumsum_df.sort_values(by='frame', inplace=True)

plt.figure(figsize=(10, 6))
#plt.plot(cumsum_df['frame'], cumsum_df['cumsum_y1'], label='Somma Cumulativa di y1')
plt.plot(frame_data['y1'], cumsum_y1, label='Somma Cumulativa di y1')
plt.xlabel('y1')
plt.ylabel('Somma Cumulativa di y1')
plt.legend()
plt.grid(True)
plt.title('Somma Cumulativa di y1 per Frame')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/7d/j3d39pm9439d4g_kq83cv2lw0000gn/T/ipykernel_14725/561863901.py in <module>
# ----> 1 cumsum_df.sort_values(by='frame', inplace=True)
#       2
#       3 plt.figure(figsize=(10, 6))
#       4 #plt.plot(cumsum_df['frame'], cumsum_df['cumsum_y1'], label='Somma Cumulativa di y1')
#       5 plt.plot(frame_data['y1'], cumsum_y1, label='Somma Cumulativa di y1')
#
# NameError: name 'cumsum_df' is not defined

# %%
df.sort_values(by='frame', inplace=True)


cumulative_y1 = []
cumulative_y2 = []


cumulative_sum_y1 = 0
cumulative_sum_y2 = 0

for index, row in df.iterrows():
    cumulative_sum_y1 += row['y1']
    cumulative_sum_y2 += row['y2']
    
    cumulative_y1.append(cumulative_sum_y1)
    cumulative_y2.append(cumulative_sum_y2)

df['cumsum_y1'] = cumulative_y1
df['cumsum_y2'] = cumulative_y2

plt.figure(figsize=(10, 6))
#plt.plot(df['frame'], df['cumsum_y1'], label='Somma Cumulativa di y1')
#plt.plot(df['frame'], df['cumsum_y2'], label='Somma Cumulativa di y2')
plt.plot(df['y1'], df['cumsum_y2'])
plt.xlabel('Frame')
plt.ylabel('Somma Cumulativa')
plt.legend()
plt.grid(True)
plt.title('Somma Cumulativa di y1 e y2 per Frame')
plt.show()
# Out:
# No handles with labels found to put in legend.
