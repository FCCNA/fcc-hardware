# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
output_folder = "/eos/user/l/lborriel/fcc-hardware/crystals-optical-characterization/20250224_crystal-transmittance/Figures"
os.makedirs(output_folder, exist_ok=True)  

BGO_c = pd.read_table('/eos/user/l/lborriel/fcc-hardware/crystals-optical-characterization/20250224_crystal-transmittance/trasmittanza cristalli/BGO C.Sample.csv', skiprows=2,sep=',', names=['wl', 't'])



fig = plt.figure(figsize=(7, 5))

plt.plot(BGO_c.wl, BGO_c.t, label='SICCAS BGO short side')
plt.xlabel('Wavelenght [nm]', size=16)
plt.ylabel('Transmittance [%]', size=16)
plt.grid()
plt.title('FCC NA - Trans. measured @ photonics lab (UNINA)', size=14)
plt.legend(fontsize=14, loc=4)
plt.xticks(np.arange(300, 750, 50))


#plt.savefig('transmittanceBGOshortside.png', dpi=300, bbox_inches='tight')
output_path = os.path.join(output_folder, 'transmittanceBGOshortside.png')  
plt.savefig(output_path, dpi=300, bbox_inches='tight')  

plt.show()

# %%
output_folder = "/eos/user/l/lborriel/fcc-hardware/crystals-optical-characterization/20250224_crystal-transmittance/Figures"
os.makedirs(output_folder, exist_ok=True)  

#BGO_c = pd.read_table('/eos/user/l/lborriel/fcc-hardware/crystals-optical-characterization/20250224_crystal-transmittance/trasmittanza cristalli/BGO C.Sample.csv', skiprows=2,sep=',', names=['wl', 't'])
sipm_3x3=pd.read_table(r'/eos/user/l/lborriel/fcc-hardware/crystals-optical-characterization/20250224_crystal-transmittance/trasmittanza cristalli/3x3 pde.csv', sep=" ", names=['wl', 't'])


fig = plt.figure(figsize=(7, 5))

plt.plot(sipm_3x3.wl,sipm_3x3.t, label='sipm 3x3 pde')
plt.xlabel('Wavelenght [nm]', size=16)
plt.ylabel('Transmittance [%]', size=16)
plt.grid()
plt.title('FCC NA - Trans. measured @ photonics lab (UNINA)', size=14)
plt.legend(fontsize=14, loc=4)
#plt.xticks(np.arange(200, 900, 50))
#plt.xlim(200, 900)
plt.ylim(0, 35)


#plt.savefig('transmittanceBGOshortside.png', dpi=300, bbox_inches='tight')
output_path = os.path.join(output_folder, 'PDE_sipm3x3.png')  
plt.savefig(output_path, dpi=300, bbox_inches='tight')  

plt.show()

# %%
BGO_l = pd.read_table('/eos/user/l/lborriel/fcc-hardware/crystals-optical-characterization/20250224_crystal-transmittance/trasmittanza cristalli/BGO L allinea.Sample.csv', skiprows=2,sep=',', names=['wl', 't'])

fig = plt.figure(figsize=(7, 5))

plt.plot(BGO_l.wl, BGO_l.t, label='BGO long side')
plt.xlabel('Wavelenght [nm]', size=16)
plt.ylabel('Transmittance [%]', size=16)
plt.grid()
plt.title('FCC NA - Trans. measured @ photonics lab (UNINA)', size=14)
plt.legend(fontsize=14, loc=4)
plt.xticks(np.arange(300, 750, 50))
plt.savefig('transmittanceBGOlongside.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
output_folder = "/eos/user/l/lborriel/fcc-hardware/crystals-optical-characterization/20250224_crystal-transmittance/Figures"
os.makedirs(output_folder, exist_ok=True)  

#BGO_c = pd.read_table('/eos/user/l/lborriel/fcc-hardware/crystals-optical-characterization/20250224_crystal-transmittance/trasmittanza cristalli/BGO C.Sample.csv', skiprows=2,sep=',', names=['wl', 't'])
BGO_c_bis = pd.read_table('/eos/user/l/lborriel/fcc-hardware/crystals-optical-characterization/20250224_crystal-transmittance/trasmittanza cristalli/BGO C 200  700.Sample.csv', skiprows=2,sep=',', names=['wl', 't'])



fig = plt.figure(figsize=(12, 8))

#plt.plot(BGO_c.wl, BGO_c.t, label='SICCAS BGO short side old')
plt.plot(BGO_c_bis.wl, BGO_c_bis.t, label='SICCAS BGO short side new')

plt.xlabel('Wavelenght [nm]', size=16)
plt.ylabel('Transmittance [%]', size=16)
plt.grid()
plt.title('FCC NA - Trans. measured @ photonics lab (UNINA)', size=14)
plt.legend(fontsize=14, loc=4)
plt.xticks(np.arange(250, 750, 50))
plt.ylim(-5,100)
plt.yticks(np.arange(-5, 100, 10))


#plt.savefig('transmittanceBGOlongandshortside.png', dpi=300, bbox_inches='tight')
output_path = os.path.join(output_folder, 'transmittanceBGOrange200_700.png')  
plt.savefig(output_path, dpi=300, bbox_inches='tight')  
plt.show()

# %%
output_folder = "/eos/user/l/lborriel/fcc-hardware/crystals-optical-characterization/20250224_crystal-transmittance/Figures"
os.makedirs(output_folder, exist_ok=True)  

#BSO_c = pd.read_table('/eos/user/l/lborriel/fcc-hardware/crystals-optical-characterization/20250224_crystal-transmittance/trasmittanza cristalli/BSO C.Sample.csv', skiprows=2,sep=',', names=['wl', 't'])
BSO_c_bis = pd.read_table('/eos/user/l/lborriel/fcc-hardware/crystals-optical-characterization/20250224_crystal-transmittance/trasmittanza cristalli/BSO C 200  700.Sample.csv', skiprows=2,sep=',', names=['wl', 't'])



fig = plt.figure(figsize=(12, 8))

#plt.plot(BSO_c.wl, BSO_c.t, label='SICCAS BSO short side old')
plt.plot(BSO_c_bis.wl, BSO_c_bis.t, label='SICCAS BSO short side new')

plt.xlabel('Wavelenght [nm]', size=16)
plt.ylabel('Transmittance [%]', size=16)
plt.grid()
plt.title('FCC NA - Trans. measured @ photonics lab (UNINA)', size=14)
plt.legend(fontsize=14, loc=4)
plt.xticks(np.arange(250, 750, 50))
plt.ylim(-5,100)
plt.yticks(np.arange(-5, 100, 10))


#plt.savefig('transmittanceBGOlongandshortside.png', dpi=300, bbox_inches='tight')
output_path = os.path.join(output_folder, 'transmittanceBSOrange200_700.png')  
plt.savefig(output_path, dpi=300, bbox_inches='tight')  
plt.show()

# %%
output_folder = "/eos/user/l/lborriel/fcc-hardware/crystals-optical-characterization/20250224_crystal-transmittance/Figures"
os.makedirs(output_folder, exist_ok=True)  

#PWO_c = pd.read_table('/eos/user/l/lborriel/fcc-hardware/crystals-optical-characterization/20250224_crystal-transmittance/trasmittanza cristalli/PWO C.Sample.csv', skiprows=2,sep=',', names=['wl', 't'])
PWO_c_bis = pd.read_table('/eos/user/l/lborriel/fcc-hardware/crystals-optical-characterization/20250224_crystal-transmittance/trasmittanza cristalli/PWO C 200 700.Sample.csv', skiprows=2,sep=',', names=['wl', 't'])



fig = plt.figure(figsize=(12, 8))

plt.plot(PWO_c.wl, PWO_c.t, label='SICCAS PWO short side old')
plt.plot(PWO_c_bis.wl, PWO_c_bis.t, label='SICCAS PWO short side new')

plt.xlabel('Wavelenght [nm]', size=16)
plt.ylabel('Transmittance [%]', size=16)
plt.grid()
plt.title('FCC NA - Trans. measured @ photonics lab (UNINA)', size=14)
plt.legend(fontsize=14, loc=4)
plt.xticks(np.arange(250, 750, 50))
plt.ylim(-5,100)
plt.yticks(np.arange(-5, 100, 10))


#plt.savefig('transmittanceBGOlongandshortside.png', dpi=300, bbox_inches='tight')
output_path = os.path.join(output_folder, 'transmittancePWOrange200_700.png')  
#output_path = os.path.join(output_folder, 'transmittancePWOoldandnew.png')  
plt.savefig(output_path, dpi=300, bbox_inches='tight')  
plt.show()

# %%
output_folder = "/eos/user/l/lborriel/fcc-hardware/crystals-optical-characterization/20250224_crystal-transmittance/Figures"
os.makedirs(output_folder, exist_ok=True)  

PWO_c = pd.read_table('/eos/user/l/lborriel/fcc-hardware/crystals-optical-characterization/20250224_crystal-transmittance/trasmittanza cristalli/PWO C.Sample.csv', skiprows=2,sep=',', names=['wl', 't'])
#PWO_c_bis = pd.read_table('/eos/user/l/lborriel/fcc-hardware/crystals-optical-characterization/20250224_crystal-transmittance/trasmittanza cristalli/PWO C 200 700.Sample.csv', skiprows=2,sep=',', names=['wl', 't'])



fig = plt.figure(figsize=(12, 8))

plt.plot(PWO_c.wl, PWO_c.t, label='SICCAS PWO short side old')
#plt.plot(PWO_c_bis.wl, PWO_c_bis.t, label='SICCAS PWO short side new')

plt.xlabel('Wavelenght [nm]', size=16)
plt.ylabel('Transmittance [%]', size=16)
plt.grid()
plt.title('FCC NA - Trans. measured @ photonics lab (UNINA)', size=14)
plt.legend(fontsize=14, loc=4)
plt.xticks(np.arange(250, 750, 50))
plt.ylim(-5,100)
plt.yticks(np.arange(-5, 100, 10))


#plt.savefig('transmittanceBGOlongandshortside.png', dpi=300, bbox_inches='tight')
output_path = os.path.join(output_folder, 'transmittancePWOshortside.png')  
plt.savefig(output_path, dpi=300, bbox_inches='tight')  
plt.show()

# %%
BSO_c = pd.read_table('/eos/user/l/lborriel/fcc-hardware/crystals-optical-characterization/20250224_crystal-transmittance/trasmittanza cristalli/BSO C.Sample.csv', skiprows=2,sep=',', names=['wl', 't'])


fig = plt.figure(figsize=(7, 5))

plt.plot(BSO_c.wl, BSO_c.t, label='BSO short side')
plt.xlabel('Wavelenght [nm]', size=16)
plt.ylabel('Transmittance [%]', size=16)
plt.grid()
plt.title('FCC NA - Trans. measured @ photonics lab (UNINA)', size=14)
plt.legend(fontsize=14, loc=4)
plt.xticks(np.arange(300, 750, 50))
plt.savefig('transmittanceBSOshortside.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
BSO_l = pd.read_table('/eos/user/l/lborriel/fcc-hardware/crystals-optical-characterization/20250224_crystal-transmittance/trasmittanza cristalli/BSO L allinea.Sample.csv', skiprows=2,sep=',', names=['wl', 't'])

fig = plt.figure(figsize=(7, 5))

plt.plot(BSO_l.wl, BSO_l.t, label='BSO long side')
plt.xlabel('Wavelenght [nm]', size=16)
plt.ylabel('Transmittance [%]', size=16)
plt.grid()
plt.title('FCC NA - Trans. measured @ photonics lab (UNINA)', size=14)
plt.legend(fontsize=14, loc=4)
plt.xticks(np.arange(300, 750, 50))
plt.savefig('transmittanceBSOlongside.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
BSO_c = pd.read_table('/eos/user/l/lborriel/fcc-hardware/crystals-optical-characterization/20250224_crystal-transmittance/trasmittanza cristalli/BSO C.Sample.csv', skiprows=2,sep=',', names=['wl', 't'])
BSO_l = pd.read_table('/eos/user/l/lborriel/fcc-hardware/crystals-optical-characterization/20250224_crystal-transmittance/trasmittanza cristalli/BSO L allinea.Sample.csv', skiprows=2,sep=',', names=['wl', 't'])

fig = plt.figure(figsize=(10, 8))

plt.plot(BSO_c.wl, BSO_c.t, label='BSO short side')
plt.plot(BSO_l.wl, BSO_l.t, label='BSO long side')
plt.xlabel('Wavelenght [nm]', size=16)
plt.ylabel('Transmittance [%]', size=16)
plt.grid()
plt.title('FCC NA - Trans. measured @ photonics lab (UNINA)', size=14)
plt.legend(fontsize=14, loc=4)
plt.xticks(np.arange(300, 750, 50))
plt.ylim(-5,100)
plt.yticks(np.arange(-5, 100, 10))

plt.savefig('transmittanceBSOlongandshortside.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
PWO_c = pd.read_table('/eos/user/l/lborriel/fcc-hardware/crystals-optical-characterization/20250224_crystal-transmittance/trasmittanza cristalli/PWO C.Sample.csv', skiprows=2,sep=',', names=['wl', 't'])



fig = plt.figure(figsize=(7, 5))

plt.plot(PWO_c.wl, PWO_c.t, label='PWO short side')
plt.xlabel('Wavelenght [nm]', size=16)
plt.ylabel('Transmittance [%]', size=16)
plt.grid()
plt.title('FCC NA - Trans. measured @ photonics lab (UNINA)', size=14)
plt.legend(fontsize=14, loc=4)
plt.xticks(np.arange(300, 750, 50))
plt.savefig('transmittancePWOshortside.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
PWO_l = pd.read_table('/eos/user/l/lborriel/fcc-hardware/crystals-optical-characterization/20250224_crystal-transmittance/trasmittanza cristalli/PWO L allinea.Sample.csv', skiprows=2,sep=',', names=['wl', 't'])

fig = plt.figure(figsize=(7, 5))

plt.plot(PWO_l.wl, PWO_l.t, label='PWO long side')
plt.xlabel('Wavelenght [nm]', size=16)
plt.ylabel('Transmittance [%]', size=16)
plt.grid()
plt.title('FCC NA - Trans. measured @ photonics lab (UNINA)', size=14)
plt.legend(fontsize=14, loc=4)
plt.xticks(np.arange(300, 750, 50))
plt.savefig('transmittancePWOlongside.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
PWO_c = pd.read_table('/eos/user/l/lborriel/fcc-hardware/crystals-optical-characterization/20250224_crystal-transmittance/trasmittanza cristalli/PWO C.Sample.csv', skiprows=2,sep=',', names=['wl', 't'])
PWO_l = pd.read_table('/eos/user/l/lborriel/fcc-hardware/crystals-optical-characterization/20250224_crystal-transmittance/trasmittanza cristalli/PWO L allinea.Sample.csv', skiprows=2,sep=',', names=['wl', 't'])



fig = plt.figure(figsize=(10, 8))

plt.plot(PWO_c.wl, PWO_c.t, label='PWO short side')
plt.plot(PWO_l.wl, PWO_l.t, label='PWO long side')

plt.xlabel('Wavelenght [nm]', size=16)
plt.ylabel('Transmittance [%]', size=16)
plt.grid()
plt.title('FCC NA - Trans. measured @ photonics lab (UNINA)', size=14)
plt.legend(fontsize=14, loc=4)
plt.xticks(np.arange(300, 750, 50))
plt.ylim(-5,100)
plt.yticks(np.arange(-5, 100, 10))


plt.savefig('transmittancePWOlongandshortside.png', dpi=300, bbox_inches='tight')
plt.show()
